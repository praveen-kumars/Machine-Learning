# %%
import pandas as pd
df=pd.read_csv('/home/praveen/Downloads/weather.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
rows,columns=df.shape
rows
# Out:
# 6

# %%
columns
# Out:
# 4

# %%
df.head(2)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny

# %%
df.tail(1)
# Out:
#         day  temperature  windspeed  event
# 5  1/6/2017           31          2  Sunny

# %%
df[2:5]
# Out:
#         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow
# 4  1/5/2017           32          4  Rain

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df.event
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %%
df['event']
# Out:
# 0     Rain
# 1    Sunny
# 2     Snow
# 3     Snow
# 4     Rain
# 5    Sunny
# Name: event, dtype: object

# %%
type(df['event'])
# Out:
# pandas.core.series.Series

# %%
df[['event','day']]
# Out:
#    event       day
# 0   Rain  1/1/2017
# 1  Sunny  1/2/2017
# 2   Snow  1/3/2017
# 3   Snow  1/4/2017
# 4   Rain  1/5/2017
# 5  Sunny  1/6/2017

# %%
df['temperature'].std()
# Out:
# 3.8297084310253524

# %%
df.describe()
# Out:
#        temperature  windspeed
# count     6.000000   6.000000
# mean     30.333333   4.666667
# std       3.829708   2.338090
# min      24.000000   2.000000
# 25%      28.750000   2.500000
# 50%      31.500000   5.000000
# 75%      32.000000   6.750000
# max      35.000000   7.000000

# %%
df[df.temperature>=32]
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 4  1/5/2017           32          4   Rain

# %%
df[['day','temperature']][df.temperature==df['temperature'].max()]
# Out:
#         day  temperature
# 1  1/2/2017           35

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df.set_index('day',inplace=True)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
df
# Out:
#           temperature  windspeed  event
# day
# 1/1/2017           32          6   Rain
# 1/2/2017           35          7  Sunny
# 1/3/2017           28          2   Snow
# 1/4/2017           24          7   Snow
# 1/5/2017           32          4   Rain
# 1/6/2017           31          2  Sunny

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#    event       day  temperature  windspeed
# 0   Rain  1/1/2017           32          6
# 1  Sunny  1/2/2017           35          7
# 2   Snow  1/3/2017           28          2
# 3   Snow  1/4/2017           24          7
# 4   Rain  1/5/2017           32          4
# 5  Sunny  1/6/2017           31          2

# %%
df.set_index('event',inplace=True)
df
# Out:
#             day  temperature  windspeed
# event
# Rain   1/1/2017           32          6
# Sunny  1/2/2017           35          7
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7
# Rain   1/5/2017           32          4
# Sunny  1/6/2017           31          2

# %%
df.loc['Snow']
# Out:
#             day  temperature  windspeed
# event
# Snow   1/3/2017           28          2
# Snow   1/4/2017           24          7

# %% [markdown]
# DIFFERENT WAYS OF CREATING DATAFRAME

# %%
import pandas as pd
df=pd.read_csv('/home/praveen/Downloads/weather.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
import pandas as pd
df=pd.read_excel('/home/praveen/Downloads/weather_data.xlsx','Sheet1')
df
# Out:
#          day  temperature  windspeed  event
# 0 2017-01-01           32          6   Rain
# 1 2017-01-02           35          7  Sunny
# 2 2017-01-03           28          2   Snow

# %%
weather_data=[
   ('1/1/2017',32,6,'Rain'),
   ('1/2/2017',35,7,'Sunny'),
   ('1/3/2017',28,2,'Snow')
]
df=pd.DataFrame(weather_data, columns=['day','temperature','windspeed','event'])
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
import pandas as pd
df=pd.read_csv('/home/praveen/Downloads/stack.csv',header=None,names=['ticket','eps','revenue','price','people'])
df
# Out:
#     ticket            eps  revenue  price         people
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
import pandas as pd
df=pd.read_csv('/home/praveen/Downloads/stack.csv',na_values=['not availbale','n.a.'])
df
# Out:
#   tickers            eps  revenue   price         people
# 0   GOOGL          27.82       87   845.0     larry page
# 1     WMT           4.61      484    65.0            NaN
# 2    MSFT             -1       85    64.0     bill gates
# 3    RIL   not available       50  1023.0  mukesh ambani
# 4    TATA            5.6       -1     NaN     ratan tata

# %%
df.to_excel('new.xlsx',index=False)

# %%
df.columns
# Out:
# Index(['tickers', 'eps', 'revenue', 'price', 'people'], dtype='object')

# %%
df.to_csv('new.csv',columns=['tickers'])

# %%
df.to_csv('new.csv',header=False)

# %%
import pandas as pd
df=pd.read_excel("new.xlsx","Sheet1")
df
# Out:
#     ticket            eps  revenue  price         people
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65           n.a.
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
import pandas as pd
def convert_peoplecall(cell):
    if cell=="n.a.":
       return 'sam walton'
    return cell
df=pd.read_excel("new.xlsx","Sheet1",converters={'people':convert_peoplecall})
df
# Out:
#     ticket            eps  revenue  price         people
# 0  tickers            eps  revenue  price         people
# 1    GOOGL          27.82       87    845     larry page
# 2      WMT           4.61      484     65     sam walton
# 3     MSFT             -1       85     64     bill gates
# 4     RIL   not available       50   1023  mukesh ambani
# 5     TATA            5.6       -1   n.a.     ratan tata

# %%
df.to_excel('new1.xlsx',sheet_name='stocks',startrow=1,startcol=2,index=False)

# %%
df_stocks = pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

df_weather =  pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']
})

# %%
with pd.ExcelWriter('stocks_weather.xlsx') as writer:
    df_stocks.to_excel(writer, sheet_name="stocks")
    df_weather.to_excel(writer, sheet_name="weather")

# %%
import pandas as pd
df=pd.read_csv('/home/praveen/Downloads/weather.csv',parse_dates=['day'])
type(df.day[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
import pandas as pd
df=pd.read_csv('/home/praveen/Downloads/weather.csv',parse_dates=['day'])
df
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        9.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08          NaN        NaN   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0   Sunny

# %%
df.set_index('day',inplace=True)
df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna(0)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          0.0        9.0   Sunny
# 2017-01-05         28.0        0.0    Snow
# 2017-01-06          0.0        7.0       0
# 2017-01-07         32.0        0.0    Rain
# 2017-01-08          0.0        0.0   Sunny
# 2017-01-09          0.0        0.0       0
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna({'temperature':0,'windspeed':1,'event':'noevent'})
new_df
# Out:
#             temperature  windspeed    event
# day
# 2017-01-01         32.0        6.0     Rain
# 2017-01-04          0.0        9.0    Sunny
# 2017-01-05         28.0        1.0     Snow
# 2017-01-06          0.0        7.0  noevent
# 2017-01-07         32.0        1.0     Rain
# 2017-01-08          0.0        1.0    Sunny
# 2017-01-09          0.0        1.0  noevent
# 2017-01-10         34.0        8.0   Cloudy
# 2017-01-11         40.0       12.0    Sunny

# %%
new_df=df.fillna(method='ffill')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        7.0   Sunny
# 2017-01-09         32.0        7.0   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.fillna(method='bfill',axis='columns')
new_df
# Out:
#            temperature windspeed   event
# day
# 2017-01-01          32         6    Rain
# 2017-01-04           9         9   Sunny
# 2017-01-05          28      Snow    Snow
# 2017-01-06           7         7     NaN
# 2017-01-07          32      Rain    Rain
# 2017-01-08       Sunny     Sunny   Sunny
# 2017-01-09         NaN       NaN     NaN
# 2017-01-10          34         8  Cloudy
# 2017-01-11          40        12   Sunny

# %%
new_df=df.fillna(method='ffill',limit=1)
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04         32.0        9.0   Sunny
# 2017-01-05         28.0        9.0    Snow
# 2017-01-06         28.0        7.0    Snow
# 2017-01-07         32.0        7.0    Rain
# 2017-01-08         32.0        NaN   Sunny
# 2017-01-09          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.interpolate(method='time')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01    32.000000       6.00    Rain
# 2017-01-04    29.000000       9.00   Sunny
# 2017-01-05    28.000000       8.00    Snow
# 2017-01-06    30.000000       7.00     NaN
# 2017-01-07    32.000000       7.25    Rain
# 2017-01-08    32.666667       7.50   Sunny
# 2017-01-09    33.333333       7.75     NaN
# 2017-01-10    34.000000       8.00  Cloudy
# 2017-01-11    40.000000      12.00   Sunny

# %%
new_df=df.dropna()
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
new_df=df.dropna(how='all')
new_df
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
dt=pd.date_range("01-01-2017","01-11-2017")
idx=pd.DatetimeIndex(dt)
df=df.reindex(idx)
df
# Out:
#             temperature  windspeed   event
# 2017-01-01         32.0        6.0    Rain
# 2017-01-02          NaN        NaN     NaN
# 2017-01-03          NaN        NaN     NaN
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/home/praveen/Downloads/weather.csv')
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
new_df=df.replace(-99999,np.NaN)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
new_df=df.replace({'temperature':-99999,
                   'windspeed':-99999,
                  'event':'0'},np.NaN)
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0    NaN
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0    NaN

# %%
new_df=df.replace({-99999:np.NaN,'0':'sunny'})
new_df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0  sunny
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0  sunny

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/home/praveen/Downloads/wethercity.csv')
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g=df.groupby("city")
g

# %%
for city,city_df in g:
    print(city)
    print(city_df)
# Out:
# mumbai
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain
# new york
#         day      city  temperature  windspeed  event
# 0  1/1/2017  new york           32          6   Rain
# 1  1/2/2017  new york           36          7  Sunny
# 2  1/3/2017  new york           28         12   Snow
# 3  1/4/2017  new york           33          7  Sunny
# paris
#          day   city  temperature  windspeed   event
# 8   1/1/2017  paris           45         20   Sunny
# 9   1/2/2017  paris           50         13  Cloudy
# 10  1/3/2017  paris           54          8  Cloudy
# 11  1/4/2017  paris           42         10  Cloudy

# %%
g.get_group('mumbai')
# Out:
#         day    city  temperature  windspeed  event
# 4  1/1/2017  mumbai           90          5  Sunny
# 5  1/2/2017  mumbai           85         12    Fog
# 6  1/3/2017  mumbai           87         15    Fog
# 7  1/4/2017  mumbai           92          5   Rain

# %%
g.max()
# Out:
#                day  temperature  windspeed  event
# city
# mumbai    1/4/2017           92         15  Sunny
# new york  1/4/2017           36         12  Sunny
# paris     1/4/2017           54         20  Sunny

# %%
g.std()
# Out:
#           temperature  windspeed
# city
# mumbai       3.109126   5.057997
# new york     3.304038   2.708013
# paris        5.315073   5.251984

# %%
g.mean()
# Out:
#           temperature  windspeed
# city
# mumbai          88.50       9.25
# new york        32.25       8.00
# paris           47.75      12.75

# %%
g.describe()
# Out:
#          temperature                                                   \
#                count   mean       std   min    25%   50%    75%   max
# city
# mumbai           4.0  88.50  3.109126  85.0  86.50  88.5  90.50  92.0
# new york         4.0  32.25  3.304038  28.0  31.00  32.5  33.75  36.0
# paris            4.0  47.75  5.315073  42.0  44.25  47.5  51.00  54.0
#
#          windspeed
#              count   mean       std  min   25%   50%    75%   max
# city
# mumbai         4.0   9.25  5.057997  5.0  5.00   8.5  12.75  15.0
# new york       4.0   8.00  2.708013  6.0  6.75   7.0   8.25  12.0
# paris          4.0  12.75  5.251984  8.0  9.50  11.5  14.75  20.0

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai      AxesSubplot(0.125,0.125;0.775x0.755)
# new york    AxesSubplot(0.125,0.125;0.775x0.755)
# paris       AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
import pandas as pd

india_weather = pd.DataFrame({
    "city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30],
    "humidity": [80, 60, 78]
})
india_weather
# Out:
#        city  temperature  humidity
# 0    mumbai           32        80
# 1     delhi           45        60
# 2  banglore           30        78

# %%
import pandas as pd
us_weather = pd.DataFrame({
    "city": ["new york","chicago","orlando"],
    "temperature": [21,14,35],
    "humidity": [68, 65, 75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df=pd.concat([us_weather,india_weather])

# %%
df=pd.concat([us_weather,india_weather],ignore_index=True)

# %%
df=pd.concat([us_weather,india_weather],keys=['us','india'])
df
# Out:
#              city  temperature  humidity
# us    0  new york           21        68
#       1   chicago           14        65
#       2   orlando           35        75
# india 0    mumbai           32        80
#       1     delhi           45        60
#       2  banglore           30        78

# %%
df.loc['us']
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
temperature=pd.DataFrame({"city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30]},index=[0,1,2])
temperature
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed=pd.DataFrame({"city": ["delhi","mumbai"],
    "windspeed": [32,45],},index=[1,0])
windspeed
# Out:
#      city  windspeed
# 1   delhi         32
# 0  mumbai         45

# %%
df=pd.concat([temperature,windspeed],axis=1)
df
# Out:
#        city  temperature    city  windspeed
# 0    mumbai           32  mumbai       45.0
# 1     delhi           45   delhi       32.0
# 2  banglore           30     NaN        NaN

# %%
temperature
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
s=pd.Series(['Rain','dry','humid'],name='event')
s
# Out:
# 0     Rain
# 1      dry
# 2    humid
# Name: event, dtype: object

# %%
new=pd.concat([temperature,s],axis=1)
new
# Out:
#        city  temperature  event
# 0    mumbai           32   Rain
# 1     delhi           45    dry
# 2  banglore           30  humid

# %% [markdown]
# MERGE DATAFRAME

# %%
temperature=pd.DataFrame({"city": ["mumbai","delhi","banglore"],
    "temperature": [32,45,30]})
temperature
# Out:
#        city  temperature
# 0    mumbai           32
# 1     delhi           45
# 2  banglore           30

# %%
windspeed=pd.DataFrame({"city": ["delhi","mumbai",'bangalore'],
    "windspeed": [32,45,56]})
windspeed
# Out:
#         city  windspeed
# 0      delhi         32
# 1     mumbai         45
# 2  bangalore         56

# %%
dfs=pd.merge(temperature,windspeed,on='city',how='outer',indicator=True)
dfs
# Out:
#         city  temperature  windspeed      _merge
# 0     mumbai         32.0       45.0        both
# 1      delhi         45.0       32.0        both
# 2   banglore         30.0        NaN   left_only
# 3  bangalore          NaN       56.0  right_only

# %%
import pandas as pd
df=pd.read_csv('/home/praveen/Downloads/weather.csv')
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot(index='date',columns='city',values='humidity')
# Out:
# city      beijing  mumbai  new york
# date
# 5/1/2017       26      80        56
# 5/2/2017       30      83        58
# 5/3/2017       35      85        60

# %%
df
# Out:
#        date      city  temperature  humidity
# 0  5/1/2017  new york           65        56
# 1  5/2/2017  new york           66        58
# 2  5/3/2017  new york           68        60
# 3  5/1/2017    mumbai           75        80
# 4  5/2/2017    mumbai           78        83
# 5  5/3/2017    mumbai           82        85
# 6  5/1/2017   beijing           80        26
# 7  5/2/2017   beijing           77        30
# 8  5/3/2017   beijing           79        35

# %%
df.pivot_table(index='city',columns='date')
# Out:
#          humidity                   temperature
# date     5/1/2017 5/2/2017 5/3/2017    5/1/2017 5/2/2017 5/3/2017
# city
# beijing        26       30       35          80       77       79
# mumbai         80       83       85          75       78       82
# new york       56       58       60          65       66       68

# %%
df.pivot_table(index='city',columns='date',margins=True)
# Out:
#          humidity                              temperature             \
# date     5/1/2017 5/2/2017 5/3/2017        All    5/1/2017   5/2/2017
# city
# beijing        26       30       35  30.333333   80.000000  77.000000
# mumbai         80       83       85  82.666667   75.000000  78.000000
# new york       56       58       60  58.000000   65.000000  66.000000
# All            54       57       60  57.000000   73.333333  73.666667
#
#
# date       5/3/2017        All
# city
# beijing   79.000000  78.666667
# mumbai    82.000000  78.333333
# new york  68.000000  66.333333
# All       76.333333  74.444444

# %%
import pandas as pd
df=pd.read_csv('/home/praveen/Downloads/weather.csv')
df
# Out:
#          day  chicago  chennai  berlin
# 0     Monday       32       75      41
# 1    Tuesday       30       77      43
# 2  Wednesday       28       75      45
# 3   Thursday       22       82      38
# 4     Friday       30       83      30
# 5   Saturday       20       81      45
# 6     Sunday       25       77      47

# %%
df=pd.melt(df,id_vars=['day'],var_name='city',value_name='value')
df
# Out:
#           day     city  value
# 0      Monday  chicago     32
# 1     Tuesday  chicago     30
# 2   Wednesday  chicago     28
# 3    Thursday  chicago     22
# 4      Friday  chicago     30
# 5    Saturday  chicago     20
# 6      Sunday  chicago     25
# 7      Monday  chennai     75
# 8     Tuesday  chennai     77
# 9   Wednesday  chennai     75
# 10   Thursday  chennai     82
# 11     Friday  chennai     83
# 12   Saturday  chennai     81
# 13     Sunday  chennai     77
# 14     Monday   berlin     41
# 15    Tuesday   berlin     43
# 16  Wednesday   berlin     45
# 17   Thursday   berlin     38
# 18     Friday   berlin     30
# 19   Saturday   berlin     45
# 20     Sunday   berlin     47

# %%
import pandas as pd
df=pd.read_excel('/home/praveen/Downloads/stocks.xlsx',header=[0,1])
df
# Out:
#   Unnamed: 0_level_0    Price                  Price to earnings ratio (P/E)  \
#              Company Facebook Google Microsoft                      Facebook
# 0         2017-06-05      155    955        66                         37.10
# 1         2017-06-06      150    987        69                         36.98
# 2         2017-06-07      153    963        62                         36.78
# 3         2017-06-08      155   1000        61                         36.11
# 4         2017-06-09      156   1012        66                         37.07
#
#
#   Google Microsoft
# 0   32.0     30.31
# 1   31.3     30.56
# 2   31.7     30.46
# 3   31.2     30.11
# 4   30.0     31.00

# %%
df=df.stack()

df
# Out:
#               Price  Price to earnings ratio (P/E) Unnamed: 0_level_0
# 0 Company       NaN                            NaN         2017-06-05
#   Facebook    155.0                          37.10                NaT
#   Google      955.0                          32.00                NaT
#   Microsoft    66.0                          30.31                NaT
# 1 Company       NaN                            NaN         2017-06-06
#   Facebook    150.0                          36.98                NaT
#   Google      987.0                          31.30                NaT
#   Microsoft    69.0                          30.56                NaT
# 2 Company       NaN                            NaN         2017-06-07
#   Facebook    153.0                          36.78                NaT
#   Google      963.0                          31.70                NaT
#   Microsoft    62.0                          30.46                NaT
# ...

# %%
import pandas as pd
df=pd.read_excel('/home/praveen/Downloads/survey.xls')
df
# Out:
#       Name Nationality     Sex  Age Handedness
# 0    Kathy         USA  Female   23      Right
# 1    Linda         USA  Female   18      Right
# 2    Peter         USA    Male   19      Right
# 3     John         USA    Male   22       Left
# 4   Fatima   Bangadesh  Female   31       Left
# 5    Kadir   Bangadesh    Male   25       Left
# 6   Dhaval       India    Male   35       Left
# 7   Sudhir       India    Male   31       Left
# 8   Parvir       India    Male   37      Right
# 9      Yan       China  Female   52      Right
# 10    Juan       China  Female   58       Left
# 11   Liang       China    Male   43       Left

# %%
pd.crosstab(df.Nationality,df.Handedness)
# Out:
# Handedness   Left  Right
# Nationality
# Bangadesh       2      0
# China           2      1
# India           2      1
# USA             1      3

# %%
pd.crosstab(df.Sex,df.Handedness,margins=True)
# Out:
# Handedness  Left  Right  All
# Sex
# Female         2      3    5
# Male           5      2    7
# All            7      5   12

# %%
pd.crosstab(df.Sex,[df.Nationality,df.Handedness],normalize='index')
# Out:
# Nationality Bangadesh     China           India                 USA
# Handedness       Left      Left Right      Left     Right      Left     Right
# Sex
# Female       0.200000  0.200000   0.2  0.000000  0.000000  0.000000  0.400000
# Male         0.142857  0.142857   0.0  0.285714  0.142857  0.142857  0.142857

# %%
import numpy as np
pd.crosstab([df.Sex],[df.Handedness],values=df.Age,aggfunc=np.average)
# Out:
# /home/praveen/anaconda3/lib/python3.7/site-packages/numpy/lib/function_base.py:393: RuntimeWarning: Mean of empty slice.
#   avg = a.mean(axis)
# /home/praveen/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Handedness  Left  Right
# Sex
# Female      44.5   31.0
# Male        31.2   28.0

# %% [markdown]
# TIME ANALYSIS

# %%
import pandas as pd
df=pd.read_csv('/home/praveen/Downloads/stock.csv',parse_dates=['Date'],index_col='Date')
df
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
df.head(5)
# Out:
#         Date    Open    High     Low   Close    Volume
# 0 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 1 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 3 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 4 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['2017-07-05'].Close.mean()
# Out:
# 144.09

# %%
df['2017-07-07':'2017-07-01']
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848

# %%
df
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107
# ...            ...     ...     ...     ...       ...
# 2016-07-15   98.92   99.30   98.50   98.78  30136990
# 2016-07-14   97.39   98.99   97.32   98.79  38918997
# 2016-07-13   97.41   97.67   96.84   96.87  25892171
# 2016-07-12   97.17   97.70   97.12   97.42  24167463
# 2016-07-11   96.75   97.65   96.73   96.98  23794945
#
# [251 rows x 5 columns]

# %%
df.Close.resample('Q').mean().plot(kind='bar')

# %%
df.Close.resample('Q').mean().plot()

# %%
  df.head()
# Out:
#               Open    High     Low   Close    Volume
# Date
# 2017-07-07  142.90  144.75  142.90  144.18  19201712
# 2017-07-06  143.02  143.50  142.41  142.73  24128782
# 2017-07-05  143.69  144.79  142.72  144.09  21569557
# 2017-07-03  144.88  145.30  143.10  143.50  14277848
# 2017-06-30  144.45  144.96  143.78  144.02  23024107

# %%
import pandas as pd
df=pd.read_csv('/home/praveen/Downloads/apple_no_date.csv')
df.head()
# Out:
#      Open    High     Low   Close    Volume
# 0  153.17  153.33  152.22  153.18  16404088
# 1  153.58  155.45  152.89  155.45  27770715
# 2  154.34  154.45  153.46  153.93  25331662
# 3  153.90  155.81  153.78  154.45  26624926
# 4  155.02  155.98  154.48  155.37  21069647

# %%
ind=pd.date_range(start='6/1/2017',end='6/30/2017',freq='B')
ind
# Out:
# DatetimeIndex(['2017-06-01', '2017-06-02', '2017-06-05', '2017-06-06',
#                '2017-06-07', '2017-06-08', '2017-06-09', '2017-06-12',
#                '2017-06-13', '2017-06-14', '2017-06-15', '2017-06-16',
#                '2017-06-19', '2017-06-20', '2017-06-21', '2017-06-22',
#                '2017-06-23', '2017-06-26', '2017-06-27', '2017-06-28',
#                '2017-06-29', '2017-06-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
df.set_index(ind,inplace=True)
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-19  143.66  146.74  143.66  146.34  32541404
# 2017-06-20  146.87  146.87  144.94  145.01  24900073
# 2017-06-21  145.52  146.07  144.61  145.87  21265751
# 2017-06-22  145.77  146.70  145.12  145.63  19106294
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# ...

# %%
# %matplotlib inline
df.Close.plot()

# %%
df['2017-06-23':'2017-06-29']
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-23  145.13  147.16  145.11  146.28  35439389
# 2017-06-26  147.17  148.28  145.38  145.82  25692361
# 2017-06-27  145.01  146.16  143.62  143.73  24761891
# 2017-06-28  144.49  146.11  143.16  145.83  22082432
# 2017-06-29  144.71  145.13  142.28  143.68  31499368

# %%
df.asfreq('D',method='pad')
# Out:
#               Open    High     Low   Close    Volume
# 2017-06-01  153.17  153.33  152.22  153.18  16404088
# 2017-06-02  153.58  155.45  152.89  155.45  27770715
# 2017-06-03  153.58  155.45  152.89  155.45  27770715
# 2017-06-04  153.58  155.45  152.89  155.45  27770715
# 2017-06-05  154.34  154.45  153.46  153.93  25331662
# 2017-06-06  153.90  155.81  153.78  154.45  26624926
# 2017-06-07  155.02  155.98  154.48  155.37  21069647
# 2017-06-08  155.25  155.54  154.40  154.99  21250798
# 2017-06-09  155.19  155.19  146.02  148.98  64882657
# 2017-06-10  155.19  155.19  146.02  148.98  64882657
# 2017-06-11  155.19  155.19  146.02  148.98  64882657
# 2017-06-12  145.74  146.09  142.51  145.42  72307330
# 2017-06-13  147.16  147.45  145.15  146.59  34165445
# 2017-06-14  147.50  147.50  143.84  145.16  31531232
# 2017-06-15  143.32  144.48  142.21  144.29  32165373
# 2017-06-16  143.78  144.50  142.20  142.27  50361093
# 2017-06-17  143.78  144.50  142.20  142.27  50361093
# ...

# %%
ran=pd.date_range(start='1/1/2017',periods=22,freq='H')
ran
# Out:
# DatetimeIndex(['2017-01-01 00:00:00', '2017-01-01 01:00:00',
#                '2017-01-01 02:00:00', '2017-01-01 03:00:00',
#                '2017-01-01 04:00:00', '2017-01-01 05:00:00',
#                '2017-01-01 06:00:00', '2017-01-01 07:00:00',
#                '2017-01-01 08:00:00', '2017-01-01 09:00:00',
#                '2017-01-01 10:00:00', '2017-01-01 11:00:00',
#                '2017-01-01 12:00:00', '2017-01-01 13:00:00',
#                '2017-01-01 14:00:00', '2017-01-01 15:00:00',
#                '2017-01-01 16:00:00', '2017-01-01 17:00:00',
#                '2017-01-01 18:00:00', '2017-01-01 19:00:00',
#                '2017-01-01 20:00:00', '2017-01-01 21:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
df.set_index(ran,inplace=True)
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-01-02  153.17  153.33  152.22  153.18  16404088
# 2017-01-03  153.58  155.45  152.89  155.45  27770715
# 2017-01-04  154.34  154.45  153.46  153.93  25331662
# 2017-01-05  153.90  155.81  153.78  154.45  26624926
# 2017-01-06  155.02  155.98  154.48  155.37  21069647
# 2017-01-09  155.25  155.54  154.40  154.99  21250798
# 2017-01-10  155.19  155.19  146.02  148.98  64882657
# 2017-01-11  145.74  146.09  142.51  145.42  72307330
# 2017-01-12  147.16  147.45  145.15  146.59  34165445
# 2017-01-13  147.50  147.50  143.84  145.16  31531232
# 2017-01-16  143.32  144.48  142.21  144.29  32165373
# 2017-01-17  143.78  144.50  142.20  142.27  50361093
# 2017-01-18  143.66  146.74  143.66  146.34  32541404
# 2017-01-19  146.87  146.87  144.94  145.01  24900073
# 2017-01-20  145.52  146.07  144.61  145.87  21265751
# 2017-01-23  145.77  146.70  145.12  145.63  19106294
# 2017-01-24  145.13  147.16  145.11  146.28  35439389
# ...

# %%
import numpy as np
ts=pd.Series(np.random.randint(1,10,len(ran)),index=ran)
ts
# Out:
# 2017-01-01 00:00:00    6
# 2017-01-01 01:00:00    9
# 2017-01-01 02:00:00    6
# 2017-01-01 03:00:00    5
# 2017-01-01 04:00:00    6
# 2017-01-01 05:00:00    4
# 2017-01-01 06:00:00    1
# 2017-01-01 07:00:00    7
# 2017-01-01 08:00:00    2
# 2017-01-01 09:00:00    4
# 2017-01-01 10:00:00    3
# 2017-01-01 11:00:00    5
# 2017-01-01 12:00:00    6
# 2017-01-01 13:00:00    1
# 2017-01-01 14:00:00    6
# 2017-01-01 15:00:00    3
# 2017-01-01 16:00:00    5
# 2017-01-01 17:00:00    1
# 2017-01-01 18:00:00    2
# 2017-01-01 19:00:00    1
# 2017-01-01 20:00:00    9
# 2017-01-01 21:00:00    7
# Freq: H, dtype: int64

# %%
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-01-02  153.17  153.33  152.22  153.18  16404088
# 2017-01-03  153.58  155.45  152.89  155.45  27770715
# 2017-01-04  154.34  154.45  153.46  153.93  25331662
# 2017-01-05  153.90  155.81  153.78  154.45  26624926
# 2017-01-06  155.02  155.98  154.48  155.37  21069647
# 2017-01-09  155.25  155.54  154.40  154.99  21250798
# 2017-01-10  155.19  155.19  146.02  148.98  64882657
# 2017-01-11  145.74  146.09  142.51  145.42  72307330
# 2017-01-12  147.16  147.45  145.15  146.59  34165445
# 2017-01-13  147.50  147.50  143.84  145.16  31531232
# 2017-01-16  143.32  144.48  142.21  144.29  32165373
# 2017-01-17  143.78  144.50  142.20  142.27  50361093
# 2017-01-18  143.66  146.74  143.66  146.34  32541404
# 2017-01-19  146.87  146.87  144.94  145.01  24900073
# 2017-01-20  145.52  146.07  144.61  145.87  21265751
# 2017-01-23  145.77  146.70  145.12  145.63  19106294
# 2017-01-24  145.13  147.16  145.11  146.28  35439389
# ...

# %%
import pandas as pd
df=pd.read_csv('/home/praveen/Downloads/apple_no_date.csv')
df.head()
# Out:
#      Open    High     Low   Close    Volume
# 0  153.17  153.33  152.22  153.18  16404088
# 1  153.58  155.45  152.89  155.45  27770715
# 2  154.34  154.45  153.46  153.93  25331662
# 3  153.90  155.81  153.78  154.45  26624926
# 4  155.02  155.98  154.48  155.37  21069647

# %%
pd.date_range(start='7/1/2017',end='7/21/2017',freq='B')
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-04', '2017-07-05', '2017-07-06',
#                '2017-07-07', '2017-07-10', '2017-07-11', '2017-07-12',
#                '2017-07-13', '2017-07-14', '2017-07-17', '2017-07-18',
#                '2017-07-19', '2017-07-20', '2017-07-21'],
#               dtype='datetime64[ns]', freq='B')

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

us_cal = CustomBusinessDay(calendar=USFederalHolidayCalendar())

rng = pd.date_range(start="7/1/2017",end="8/2/2017", freq=us_cal)
rng
# Out:
# DatetimeIndex(['2017-07-03', '2017-07-05', '2017-07-06', '2017-07-07',
#                '2017-07-10', '2017-07-11', '2017-07-12', '2017-07-13',
#                '2017-07-14', '2017-07-17', '2017-07-18', '2017-07-19',
#                '2017-07-20', '2017-07-21', '2017-07-24', '2017-07-25',
#                '2017-07-26', '2017-07-27', '2017-07-28', '2017-07-31',
#                '2017-08-01', '2017-08-02'],
#               dtype='datetime64[ns]', freq='C')

# %%
df.set_index(rng,inplace=True)
df
# Out:
#               Open    High     Low   Close    Volume
# 2017-07-03  153.17  153.33  152.22  153.18  16404088
# 2017-07-05  153.58  155.45  152.89  155.45  27770715
# 2017-07-06  154.34  154.45  153.46  153.93  25331662
# 2017-07-07  153.90  155.81  153.78  154.45  26624926
# 2017-07-10  155.02  155.98  154.48  155.37  21069647
# 2017-07-11  155.25  155.54  154.40  154.99  21250798
# 2017-07-12  155.19  155.19  146.02  148.98  64882657
# 2017-07-13  145.74  146.09  142.51  145.42  72307330
# 2017-07-14  147.16  147.45  145.15  146.59  34165445
# 2017-07-17  147.50  147.50  143.84  145.16  31531232
# 2017-07-18  143.32  144.48  142.21  144.29  32165373
# 2017-07-19  143.78  144.50  142.20  142.27  50361093
# 2017-07-20  143.66  146.74  143.66  146.34  32541404
# 2017-07-21  146.87  146.87  144.94  145.01  24900073
# 2017-07-24  145.52  146.07  144.61  145.87  21265751
# 2017-07-25  145.77  146.70  145.12  145.63  19106294
# 2017-07-26  145.13  147.16  145.11  146.28  35439389
# ...

# %%
from pandas.tseries.holiday import AbstractHolidayCalendar, nearest_workday, Holiday
class myCalendar(AbstractHolidayCalendar):
    rules = [
        Holiday('My Birth Day', month=4, day=16,observance=nearest_workday),
    ]
    
my_bday = CustomBusinessDay(calendar=myCalendar())
my_bday

# %%
pd.date_range(start='4/1/2017',end='4/30/2017',freq=my_bday)
# Out:
# DatetimeIndex(['2017-04-03', '2017-04-04', '2017-04-05', '2017-04-06',
#                '2017-04-07', '2017-04-10', '2017-04-11', '2017-04-12',
#                '2017-04-13', '2017-04-14', '2017-04-18', '2017-04-19',
#                '2017-04-20', '2017-04-21', '2017-04-24', '2017-04-25',
#                '2017-04-26', '2017-04-27', '2017-04-28'],
#               dtype='datetime64[ns]', freq='C')

# %%
egypt_weekdays = "Sun Mon Tue Wed Thu"

b = CustomBusinessDay(weekmask=egypt_weekdays)

pd.date_range(start="7/1/2017",periods=20,freq=b)
# Out:
# DatetimeIndex(['2017-07-02', '2017-07-03', '2017-07-04', '2017-07-05',
#                '2017-07-06', '2017-07-09', '2017-07-10', '2017-07-11',
#                '2017-07-12', '2017-07-13', '2017-07-16', '2017-07-17',
#                '2017-07-18', '2017-07-19', '2017-07-20', '2017-07-23',
#                '2017-07-24', '2017-07-25', '2017-07-26', '2017-07-27'],
#               dtype='datetime64[ns]', freq='C')

# %%
import pandas as pd
dates = ['2017-01-05 2:30:00 PM', 'Jan 5, 2017', '01/05/2017', '2017.01.05', '2017/01/05','20170105']
pd.to_datetime(dates)
# Out:
# DatetimeIndex(['2017-01-05 14:30:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00',
#                '2017-01-05 00:00:00', '2017-01-05 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime('01/02/2017',dayfirst=True)
# Out:
# Timestamp('2017-02-01 00:00:00')

# %%
pd.to_datetime('2017$01$05',dayfirst=True, format='%Y$%m$%d')
# Out:
# Timestamp('2017-01-05 00:00:00')

# %%
pd.to_datetime('2017#01#05', format='%Y#%m#%d')
# Out:
# Timestamp('2017-01-05 00:00:00')

# %%
pd.to_datetime(['2017-01-05', 'Jan 6, 2017', 'abc'], errors='ignore')
# Out:
# Index(['2017-01-05', 'Jan 6, 2017', 'abc'], dtype='object')

# %%
pd.to_datetime(['2017-01-05', 'Jan 6, 2017', 'abc'], errors='coerce')
# Out:
# DatetimeIndex(['2017-01-05', '2017-01-06', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
current_epoch = 1501324478
dt=pd.to_datetime(current_epoch, unit='s')

# %%
df.view('int64')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-128-3aa3de75a234> in <module>
# ----> 1 df.view('int64')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'view'

# %%
import pandas as pd
y=pd.Period('2016')
y
# Out:
# Period('2016', 'A-DEC')

# %%
dir(y)
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_delta',
#  '_from_ordinal',
#  '_maybe_convert_freq',
#  '_typ',
#  'asfreq',
#  'day',
#  'dayofweek',
#  'dayofyear',
#  'days_in_month',
#  'daysinmonth',
#  'end_time',
#  'freq',
#  'freqstr',
#  'hour',
#  'is_leap_year',
#  'minute',
#  'month',
#  'now',
#  'ordinal',
#  'quarter',
#  'qyear',
#  'second',
#  'start_time',
#  'strftime',
#  'to_timestamp',
#  'week',
#  'weekday',
#  'weekofyear',
#  'year']

# %%
y.start_time
# Out:
# Timestamp('2016-01-01 00:00:00')

# %%
m=pd.Period('2011-1',freq='M')
m
# Out:
# Period('2011-01', 'M')

# %%
m.start_time
# Out:
# Timestamp('2011-01-01 00:00:00')

# %%
m.end_time
# Out:
# Timestamp('2011-01-31 23:59:59.999999999')

# %%
m+1
# Out:
# Period('2011-02', 'M')

# %%
d=pd.Period('2017-02-28',freq='D')
d
# Out:
# Period('2017-02-28', 'D')

# %%
d=d+1

# %%
d.start_time
# Out:
# Timestamp('2017-03-01 00:00:00')

# %%
d.end_time
# Out:
# Timestamp('2017-03-01 23:59:59.999999999')

# %%
d=pd.Period('2017-02-28 23:00:00',freq='H')
d
# Out:
# Period('2017-02-28 23:00', 'H')

# %%
d.start_time
# Out:
# Timestamp('2017-02-28 23:00:00')

# %%
d.end_time
# Out:
# Timestamp('2017-02-28 23:59:59.999999999')

# %%
d-6
# Out:
# Period('2017-02-28 17:00', 'H')

# %%
d+pd.offsets.Hour(5)
# Out:
# Period('2017-03-01 04:00', 'H')

# %%
q=pd.Period('2017Q1',freq='Q-JAN')
q
# Out:
# Period('2017Q1', 'Q-JAN')

# %%
q.start_time
# Out:
# Timestamp('2016-02-01 00:00:00')
